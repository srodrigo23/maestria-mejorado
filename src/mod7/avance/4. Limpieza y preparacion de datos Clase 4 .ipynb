# %% [markdown]
# Durante el proceso de análisis y modelado de datos, se dedica una cantidad significativa de tiempo a la preparación de los datos: **cargarlos, limpiarlos, transformarlos y reorganizarlos**. Estas tareas ocupan el 80% o más del tiempo de un analista, dado que a veces la forma en que se almacenan los datos en archivos o bases de datos no tiene el formato adecuado para una tarea en particular.
#
# Pandas, junto con las funciones integradas del lenguaje Python, proporciona un conjunto de herramientas rápidas, flexible y de alto nivel permiten manipular datos en la forma correcta.

# %% [markdown]
# # Manejando datos perdidos

# %% [markdown]
# La falta de datos es algo habitual en muchas aplicaciones de análisis de datos.
#
# Uno de los objetivos de Pandas es hacer que trabajar con datos faltantes sea lo menos complicado posible. Por ejemplo, todas las estadísticas descriptivas de los objetos de Pandas excluyen los datos faltantes de forma predeterminada.

# %%
import pandas as pd

# %%
ejemplo = pd.read_csv('Store_CAed.txt',sep=',') #anadimos la extension archivo
ejemplo
# Out:
#       ProductVariety  MarketingSpend  CustomerFootfall  StoreSize  \
# 0              581.0              29            1723.0      186.0
# 1              382.0              31            1218.0      427.0
# 2              449.0              35            2654.0        NaN
# 3              666.0               9            2591.0      159.0
# 4              657.0              35            2151.0      275.0
# ...              ...             ...               ...        ...
# 1645           295.0              15            2681.0      235.0
# 1646           761.0               8            1398.0      456.0
# 1647           405.0              21            1490.0      465.0
# 1648           359.0              41            2042.0      350.0
# 1649           525.0              24            1772.0      178.0
#
#       EmployeeEfficiency  StoreAge  CompetitorDistance  PromotionsCount  \
# 0                   84.9       1.0                12.0                6
# 1                   75.8      18.0                11.0                6
# 2                   92.8      14.0                11.0                6
# 3                   66.3      11.0                11.0                4
# 4                   89.1      28.0                12.0                7
# ...                  ...       ...                 ...              ...
# 1645                58.5      15.0                10.0                5
# 1646                78.5      26.0                14.0                4
# 1647                76.7      18.0                12.0                5
# 1648                67.6       2.0                 6.0                7
# 1649                73.0      29.0                18.0                6
#
#       EconomicIndicator  StoreLocation StoreCategory  MonthlySalesRevenue
# 0                 108.3    Los Angeles   Electronics               284.90
# 1                  97.8    Los Angeles   Electronics               308.21
# 2                 101.1    Los Angeles       Grocery               292.11
# 3                 115.1     Sacramento      Clothing               279.61
# 4                   NaN      Palo Alto   Electronics               359.71
# ...                 ...            ...           ...                  ...
# 1645               88.7     Sacramento      Clothing               273.55
# 1646               95.1  San Francisco      Clothing               432.82
# 1647               73.0    Los Angeles      Clothing               303.52
# 1648              105.0      Palo Alto      Clothing               241.39
# 1649               60.0    Los Angeles   Electronics               259.04
#
# [1650 rows x 12 columns]

# %%
ejemplo.isnull() #Cual sera el resultado?
# Out:
#       ProductVariety  MarketingSpend  CustomerFootfall  StoreSize  \
# 0              False           False             False      False
# 1              False           False             False      False
# 2              False           False             False       True
# 3              False           False             False      False
# 4              False           False             False      False
# ...              ...             ...               ...        ...
# 1645           False           False             False      False
# 1646           False           False             False      False
# 1647           False           False             False      False
# 1648           False           False             False      False
# 1649           False           False             False      False
#
#       EmployeeEfficiency  StoreAge  CompetitorDistance  PromotionsCount  \
# 0                  False     False               False            False
# 1                  False     False               False            False
# 2                  False     False               False            False
# 3                  False     False               False            False
# 4                  False     False               False            False
# ...                  ...       ...                 ...              ...
# 1645               False     False               False            False
# 1646               False     False               False            False
# 1647               False     False               False            False
# 1648               False     False               False            False
# 1649               False     False               False            False
#
#       EconomicIndicator  StoreLocation  StoreCategory  MonthlySalesRevenue
# 0                 False          False          False                False
# 1                 False          False          False                False
# 2                 False          False          False                False
# 3                 False          False          False                False
# 4                  True          False          False                False
# ...                 ...            ...            ...                  ...
# 1645              False          False          False                False
# 1646              False          False          False                False
# 1647              False          False          False                False
# 1648              False          False          False                False
# 1649              False          False          False                False
#
# [1650 rows x 12 columns]

# %%
#Buscamos si tenemos datos NAN a lo largo de todo el dataset
ejemplo.isnull().sum()
# Out:
# ProductVariety         1
# MarketingSpend         0
# CustomerFootfall       2
# StoreSize              2
# EmployeeEfficiency     1
# StoreAge               1
# CompetitorDistance     1
# PromotionsCount        0
# EconomicIndicator      2
# StoreLocation          0
# StoreCategory          0
# MonthlySalesRevenue    1
# dtype: int64

# %%
#Cual es la diferencia entre NAN y NA?
ejemplo.dropna()#??
# Out:
#       ProductVariety  MarketingSpend  CustomerFootfall  StoreSize  \
# 0              581.0              29            1723.0      186.0
# 1              382.0              31            1218.0      427.0
# 3              666.0               9            2591.0      159.0
# 5              182.0              43            1789.0      312.0
# 6              341.0              29            1868.0      400.0
# ...              ...             ...               ...        ...
# 1645           295.0              15            2681.0      235.0
# 1646           761.0               8            1398.0      456.0
# 1647           405.0              21            1490.0      465.0
# 1648           359.0              41            2042.0      350.0
# 1649           525.0              24            1772.0      178.0
#
#       EmployeeEfficiency  StoreAge  CompetitorDistance  PromotionsCount  \
# 0                   84.9       1.0                12.0                6
# 1                   75.8      18.0                11.0                6
# 3                   66.3      11.0                11.0                4
# 5                   88.8      13.0                 8.0                8
# 6                   65.2       8.0                12.0                6
# ...                  ...       ...                 ...              ...
# 1645                58.5      15.0                10.0                5
# 1646                78.5      26.0                14.0                4
# 1647                76.7      18.0                12.0                5
# 1648                67.6       2.0                 6.0                7
# 1649                73.0      29.0                18.0                6
#
#       EconomicIndicator  StoreLocation StoreCategory  MonthlySalesRevenue
# 0                 108.3    Los Angeles   Electronics               284.90
# 1                  97.8    Los Angeles   Electronics               308.21
# 3                 115.1     Sacramento      Clothing               279.61
# 5                  70.4      Palo Alto   Electronics               258.21
# 6                  99.3  San Francisco   Electronics               240.30
# ...                 ...            ...           ...                  ...
# 1645               88.7     Sacramento      Clothing               273.55
# 1646               95.1  San Francisco      Clothing               432.82
# 1647               73.0    Los Angeles      Clothing               303.52
# 1648              105.0      Palo Alto      Clothing               241.39
# 1649               60.0    Los Angeles   Electronics               259.04
#
# [1639 rows x 12 columns]

# %% [markdown]
# **NA = Not available**
#
# En las aplicaciones estadísticas, los datos de NA pueden ser datos que no existen o que existen pero no se observaron (debido a problemas con la recopilación de datos, por ejemplo). Al limpiar los datos para el análisis, a menudo es importante realizar un análisis de los datos faltantes para identificar problemas de recopilación de datos o posibles sesgos en los datos causados **por la falta de datos.**

# %%
ejemplo.dropna()
# Out:
#       ProductVariety  MarketingSpend  CustomerFootfall  StoreSize  \
# 0              581.0              29            1723.0      186.0
# 1              382.0              31            1218.0      427.0
# 3              666.0               9            2591.0      159.0
# 5              182.0              43            1789.0      312.0
# 6              341.0              29            1868.0      400.0
# ...              ...             ...               ...        ...
# 1645           295.0              15            2681.0      235.0
# 1646           761.0               8            1398.0      456.0
# 1647           405.0              21            1490.0      465.0
# 1648           359.0              41            2042.0      350.0
# 1649           525.0              24            1772.0      178.0
#
#       EmployeeEfficiency  StoreAge  CompetitorDistance  PromotionsCount  \
# 0                   84.9       1.0                12.0                6
# 1                   75.8      18.0                11.0                6
# 3                   66.3      11.0                11.0                4
# 5                   88.8      13.0                 8.0                8
# 6                   65.2       8.0                12.0                6
# ...                  ...       ...                 ...              ...
# 1645                58.5      15.0                10.0                5
# 1646                78.5      26.0                14.0                4
# 1647                76.7      18.0                12.0                5
# 1648                67.6       2.0                 6.0                7
# 1649                73.0      29.0                18.0                6
#
#       EconomicIndicator  StoreLocation StoreCategory  MonthlySalesRevenue
# 0                 108.3    Los Angeles   Electronics               284.90
# 1                  97.8    Los Angeles   Electronics               308.21
# 3                 115.1     Sacramento      Clothing               279.61
# 5                  70.4      Palo Alto   Electronics               258.21
# 6                  99.3  San Francisco   Electronics               240.30
# ...                 ...            ...           ...                  ...
# 1645               88.7     Sacramento      Clothing               273.55
# 1646               95.1  San Francisco      Clothing               432.82
# 1647               73.0    Los Angeles      Clothing               303.52
# 1648              105.0      Palo Alto      Clothing               241.39
# 1649               60.0    Los Angeles   Electronics               259.04
#
# [1639 rows x 12 columns]

# %%
print(len(ejemplo)-len(ejemplo.dropna()))
# Out:
# 11

# %%
ejemplo = ejemplo.dropna()
len(ejemplo)
# Out:
# 1639

# %% [markdown]
# ![ManejarNA.png](attachment:ManejarNA.png)

# %%
#Que pasa en el siguiente caso?
import numpy as np

data = pd.DataFrame([
    [1.0, 6.5, 5,np.nan],
    [1.0, np.nan, np.nan],
    [np.nan, np.nan, np.nan],
    [np.nan, 6.5, 2,np.nan],
    [3,6,7,np.nan]])
data
# Out:
#      0    1    2   3
# 0  1.0  6.5  5.0 NaN
# 1  1.0  NaN  NaN NaN
# 2  NaN  NaN  NaN NaN
# 3  NaN  6.5  2.0 NaN
# 4  3.0  6.0  7.0 NaN

# %%
cleaned = data.dropna()
cleaned
# Out:
# Empty DataFrame
# Columns: [0, 1, 2, 3]
# Index: []

# %%
data.dropna(how = 'all') #axis sin especificar por defecto es?
# Out:
#      0    1    2   3
# 0  1.0  6.5  5.0 NaN
# 1  1.0  NaN  NaN NaN
# 3  NaN  6.5  2.0 NaN
# 4  3.0  6.0  7.0 NaN

# %%
data
# Out:
#      0    1    2   3
# 0  1.0  6.5  5.0 NaN
# 1  1.0  NaN  NaN NaN
# 2  NaN  NaN  NaN NaN
# 3  NaN  6.5  2.0 NaN
# 4  3.0  6.0  7.0 NaN

# %%
data.dropna(axis = 1, how = 'all')
# Out:
#      0    1    2
# 0  1.0  6.5  5.0
# 1  1.0  NaN  NaN
# 2  NaN  NaN  NaN
# 3  NaN  6.5  2.0
# 4  3.0  6.0  7.0

# %% [markdown]
# # Llenado datos perdidos

# %% [markdown]
# En lugar de filtrar los datos faltantes (y posiblemente descartar otros datos junto con ellos), es posible que se desee rellenar los “vacíos” de varias maneras.
#
# Para la mayoría de los propósitos, el método **fillna** es la función ideal para usar.

# %%
df = pd.DataFrame(np.random.randn(7, 3))
df.iloc[1:4, 1] = np.nan
df.iloc[:2, 2] = np.nan
df
# Out:
#           0         1         2
# 0  0.091187 -1.323761       NaN
# 1  0.921614       NaN       NaN
# 2 -0.903302       NaN  0.772081
# 3 -0.647301       NaN -1.162439
# 4 -1.841524  2.082399  0.646546
# 5 -1.459472 -1.511333  0.514235
# 6  1.201264 -1.459481  1.270230

# %%
df.fillna(900) #Objeto memoria temporal
# Out:
#           0           1           2
# 0  0.091187   -1.323761  900.000000
# 1  0.921614  900.000000  900.000000
# 2 -0.903302  900.000000    0.772081
# 3 -0.647301  900.000000   -1.162439
# 4 -1.841524    2.082399    0.646546
# 5 -1.459472   -1.511333    0.514235
# 6  1.201264   -1.459481    1.270230

# %%
df
# Out:
#           0         1         2
# 0  0.091187 -1.323761       NaN
# 1  0.921614       NaN       NaN
# 2 -0.903302       NaN  0.772081
# 3 -0.647301       NaN -1.162439
# 4 -1.841524  2.082399  0.646546
# 5 -1.459472 -1.511333  0.514235
# 6  1.201264 -1.459481  1.270230

# %%
df.ffill() #Propagamos el ultimo valor observado
# Out:
#           0         1         2
# 0  0.091187 -1.323761       NaN
# 1  0.921614 -1.323761       NaN
# 2 -0.903302 -1.323761  0.772081
# 3 -0.647301 -1.323761 -1.162439
# 4 -1.841524  2.082399  0.646546
# 5 -1.459472 -1.511333  0.514235
# 6  1.201264 -1.459481  1.270230

# %%
df.mean()
# Out:
# 0   -0.376791
# 1   -0.553044
# 2    0.408131
# dtype: float64

# %%
df
# Out:
#           0         1         2
# 0  0.091187 -1.323761       NaN
# 1  0.921614       NaN       NaN
# 2 -0.903302       NaN  0.772081
# 3 -0.647301       NaN -1.162439
# 4 -1.841524  2.082399  0.646546
# 5 -1.459472 -1.511333  0.514235
# 6  1.201264 -1.459481  1.270230

# %%
#Tambien podemos llenar los datos perdidos con valores estadisticos.
df.fillna(df.mean())
# Out:
#           0         1         2
# 0  0.091187 -1.323761  0.408131
# 1  0.921614 -0.553044  0.408131
# 2 -0.903302 -0.553044  0.772081
# 3 -0.647301 -0.553044 -1.162439
# 4 -1.841524  2.082399  0.646546
# 5 -1.459472 -1.511333  0.514235
# 6  1.201264 -1.459481  1.270230

# %%
df = df.fillna(df.mean())

# %%
df.fillna(900, inplace = True) #Objeto memoria temporal es asignado al mismo dataframe

# %%
df
# Out:
#           0           1           2
# 0  0.091187   -1.323761  900.000000
# 1  0.921614  900.000000  900.000000
# 2 -0.903302  900.000000    0.772081
# 3 -0.647301  900.000000   -1.162439
# 4 -1.841524    2.082399    0.646546
# 5 -1.459472   -1.511333    0.514235
# 6  1.201264   -1.459481    1.270230

# %% [markdown]
# # Detectando y filtrando Outliers

# %%
#Filtrar datos con base algun criterio por columna:
datos_filtrados = df[df[0]>=0] #En la condicion se puede adicionar cuantas condiciones de filtrado se deseen
datos_filtrados
# Out:
#           0           1          2
# 0  0.091187   -1.323761  900.00000
# 1  0.921614  900.000000  900.00000
# 6  1.201264   -1.459481    1.27023

# %%
#Que pasa si: ??
for x in range(0,4):
    print(datos_filtrados[0][x])
# Out:
# 0.09118734130794501
# 0.9216139086630374
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:2263, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:2273, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 2
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 3
#       1 #Que pasa si: ??
#       2 for x in range(0,4):
# ----> 3     print(datos_filtrados[0][x])
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\series.py:981, in Series.__getitem__(self, key)
#     978     return self._values[key]
#     980 elif key_is_scalar:
# --> 981     return self._get_value(key)
#     983 if is_hashable(key):
#     984     # Otherwise index.get_value will raise InvalidIndexError
#     985     try:
#     986         # For labels that don't resolve as scalars like tuples and frozensets
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\series.py:1089, in Series._get_value(self, label, takeable)
#    1086     return self._values[label]
#    1088 # Similar to Index.get_value, but we do not fall back to positional
# -> 1089 loc = self.index.get_loc(label)
#    1090 return self.index._get_values_for_loc(self, loc, label)
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 2

# %%
datos_filtrados.index
# Out:
# Int64Index([0, 1, 6], dtype='int64')

# %%
datos_filtrados.reset_index(inplace = True)

# %%
datos_filtrados.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
#Que pasa si: ??
for x in range(0,3):
    print(datos_filtrados[0][x])
# Out:
# 0.09118734130794501
# 0.9216139086630374
# 1.201263736473501

# %%
datos_filtrados
# Out:
#    index         0           1          2
# 0      0  0.091187   -1.323761  900.00000
# 1      1  0.921614  900.000000  900.00000
# 2      6  1.201264   -1.459481    1.27023

# %%
#Forma correcta:
datos_filtrados = df[df[0]>=0] #En la condicion se puede adicionar cuantas condiciones de filtrado se deseen
datos_filtrados.reset_index(drop= True,inplace = True)
datos_filtrados
# Out:
#           0           1          2
# 0  0.091187   -1.323761  900.00000
# 1  0.921614  900.000000  900.00000
# 2  1.201264   -1.459481    1.27023

# %%
#El filtrado o la transformación de valores atípicos es en gran medida una cuestión de aplicar operaciones de matriz.
dataALEATORIA = pd.DataFrame(np.random.randn(100, 4))
dataALEATORIA.describe()
# Out:
#                 0           1           2           3
# count  100.000000  100.000000  100.000000  100.000000
# mean     0.133679    0.011340    0.064974    0.122054
# std      1.045465    0.979690    0.973670    0.988513
# min     -2.131569   -2.777015   -2.513870   -1.959115
# 25%     -0.533950   -0.638171   -0.405507   -0.537372
# 50%      0.132996   -0.004889    0.102798    0.018251
# 75%      0.668147    0.691014    0.580031    0.654263
# max      3.372007    2.322827    2.455821    3.773865

# %%
# Supongamos que queremos encontrar los valores en una columna que sean mayores abs(2)
#1. Extraemos la columna sobre la que deseamos hacer la busqueda
aux = dataALEATORIA[1]
#2. Teniendo la variable auxiliar con los datos aplicamos condicion
aux[np.abs(aux)>2]
# Out:
# 1    -2.777015
# 42    2.023994
# 50    2.322827
# 99   -2.747428
# Name: 1, dtype: float64

# %%
#En su salida podemos conocer los indices y los valores que cumplen con la condicion

#En caso que deseemos aplicar la condiciones a todos los elementos del dataframe que estan junto a los que cumplen la condicion
dataALEATORIA[(np.abs(dataALEATORIA)>2).any(1)]
# Out:
# C:\Users\leydi\AppData\Local\Temp\ipykernel_22816\548636869.py:4: FutureWarning: In a future version of pandas all arguments of DataFrame.any and Series.any will be keyword-only.
#   dataALEATORIA[(np.abs(dataALEATORIA)>2).any(1)]
#            0         1         2         3
# 1  -0.843930 -2.777015  0.544476  0.369735
# 9  -0.531536  0.331501 -2.513870  0.015475
# 22 -0.058052 -0.884287  2.305432  0.674359
# 33  2.137430 -0.804002  0.062357 -0.675881
# 34 -1.811230 -1.025989 -2.068049 -0.506244
# 40  2.420116 -0.139647  0.869926 -0.673764
# 42  0.046622  2.023994  1.688133 -0.121204
# 50  1.363950  2.322827  0.437078  0.617384
# 60  0.471815 -0.793594  1.103076  2.826106
# 63 -2.045779 -0.951667 -1.139443  3.773865
# 69  0.365878  0.813220  2.044886 -0.953030
# 70  0.470279 -0.248758 -2.061998  0.160362
# 72  0.739020 -1.057902  2.455821  0.600681
# 74 -2.131569  0.977975  0.765540  0.042932
# 75  3.372007  1.092480 -1.736316  1.002751
# 77  3.023318  1.053764  0.566785 -0.532035
# 78  2.437627  0.660491 -0.898143  0.176850
# 80 -0.175655  0.489025 -2.057624  1.319939
# 82 -0.705059 -0.263632  0.218075  2.295571
# 96  2.063070  0.087558 -1.545426 -0.214299
# 99  0.926440 -2.747428  1.101848  0.510354

# %%
#En caso de querer seleccionar un subset aleatorio sin permitir repeticiones
dataALEATORIA.sample(n=25)
# Out:
#            0         1         2         3
# 37 -0.900331  1.420261  0.178478  0.324969
# 59  0.589656  0.599747 -1.114639  0.476457
# 84 -0.432971  0.474713  0.587470  1.981569
# 1  -0.843930 -2.777015  0.544476  0.369735
# 73  0.019572 -0.430123 -0.726573  0.306681
# 65 -0.386181  0.786968 -0.656080 -0.392842
# 94  1.836231 -1.612184  0.457898  0.788203
# 92 -0.245486 -0.004285 -1.299858  0.589746
# 33  2.137430 -0.804002  0.062357 -0.675881
# 13  0.651448  0.871167 -0.515340 -0.177934
# 43  0.372360 -0.104267  0.321362  0.766520
# 64  0.199602 -0.460802  0.474391 -0.700518
# 55  0.478378  0.351219 -0.501840 -0.101602
# 99  0.926440 -2.747428  1.101848  0.510354
# 50  1.363950  2.322827  0.437078  0.617384
# 36  0.164762  0.181691  1.536818  1.681584
# 25 -0.970377  0.791596 -0.888366 -0.688440
# 45  0.667633  0.381816 -0.243151 -0.150749
# 10 -0.028958  1.195334 -0.399584 -1.006585
# 41 -1.776438 -0.162426  0.927391 -0.855741
# 90  1.005886  0.183112 -0.628584 -0.141447
# 86 -0.347720 -0.275770  0.965934 -0.332821
# 68  1.554501  1.940620  0.045488 -0.862687
# 14  0.283764 -0.103634  1.522209 -0.210688
# 53  1.691206 -0.144520 -0.359978 -0.174858

# %%
#En caso de querer seleccionar un subset aleatorio permitiendo repeticiones
dataALEATORIA.sample(n=25, replace = True)
# Out:
#            0         1         2         3
# 68  1.895442  0.262712  1.060779  0.201136
# 35 -0.360591  0.002274 -1.446712 -0.567316
# 36 -0.788694  1.013529 -0.486259  0.832555
# 86 -0.111801  2.181654 -1.668206 -0.185607
# 24 -0.312978 -1.600065  1.117035 -0.517770
# 16 -0.119507 -2.081930  0.091778 -1.006800
# 45 -1.471142  0.380855 -1.225193  0.110928
# 12 -0.303523  0.287192 -1.321326 -0.333466
# 7  -1.216556 -0.692529 -1.874344 -1.454775
# 87 -1.312606  0.098016 -0.646559 -0.931530
# 96  0.789748 -0.767144  0.282148 -0.017921
# 53  1.349663 -1.239314  0.527896 -2.078535
# 11  0.904380  1.309448  1.468086 -1.041561
# 4   0.765980  0.065380  0.509855 -0.741253
# 29  0.352477  0.950301  0.859803  0.203721
# 20  0.121597  1.425112  0.196887 -0.245801
# 47  0.343685  1.560774 -0.159666  0.795975
# 52  0.143958  0.423980 -0.223942 -1.121035
# 54 -0.621066 -0.727986 -0.547769  0.690570
# 56  1.291541  0.214133  1.907251 -0.353782
# 75  1.561377 -1.921972  1.276415  0.879135
# 10 -1.467952  0.721550 -1.077206  0.526083
# 82 -0.543500 -1.990126 -0.782966 -1.391916
# 62  0.091506  0.583317 -0.339624 -0.221876
# 67  0.990624  0.118298 -0.235761 -0.502826

# %% [markdown]
# # Manipulación de datos: unir, combinar y remodelar

# %% [markdown]
# En muchas aplicaciones, los datos pueden estar distribuidos en varios archivos o bases de datos o estar organizados de una forma que no es fácil de analizar. Este acapite se centra en las herramientas que ayudan a combinar, unir y reorganizar los datos.

# %% [markdown]
# Los datos contenidos en los objetos pandas se pueden combinar de varias maneras:
#
# **• pandas.merge** conecta filas en DataFrames en función de una o más claves. Esto resulta familiar para los usuarios de SQL u otras bases de datos relacionales, ya que implementa operaciones de unión de bases de datos.
#
# **• pandas.concat** concatena o “apila” objetos a lo largo de un eje.
#
# **• El método de instancia combine_first** permite unir datos superpuestos para completar los valores faltantes en un objeto con valores de otro.

# %%
#Tenemos dos dataframes
estudiantes = pd.DataFrame({
    'ID': [101, 102, 103, 104,105],
    'Nombre': ['Ana', 'Juan', 'Luis', 'María','Jose'],
    'Curso': ['Matemáticas', 'Ciencias', 'Historia', 'Matemáticas','Ciencias']
})
estudiantes
# Out:
#     ID Nombre        Curso
# 0  101    Ana  Matemáticas
# 1  102   Juan     Ciencias
# 2  103   Luis     Historia
# 3  104  María  Matemáticas
# 4  105   Jose     Ciencias

# %%
# Segundo dataframe
calificaciones = pd.DataFrame({
    'ID': [101, 101, 102, 102,103],
    'Materia': ['Álgebra', 'Geometría', 'Física', 'Quimica','Historia Mundial'],
    'Calificación': [85, 90, 88, 65, 75]
})

calificaciones
# Out:
#     ID           Materia  Calificación
# 0  101           Álgebra            85
# 1  101         Geometría            90
# 2  102            Física            88
# 3  102           Quimica            65
# 4  103  Historia Mundial            75

# %%
pd.merge(estudiantes,calificaciones)
# Out:
#     ID Nombre        Curso           Materia  Calificación
# 0  101    Ana  Matemáticas           Álgebra            85
# 1  101    Ana  Matemáticas         Geometría            90
# 2  102   Juan     Ciencias            Física            88
# 3  102   Juan     Ciencias           Quimica            65
# 4  103   Luis     Historia  Historia Mundial            75

# %%
pd.merge(estudiantes,calificaciones, on ="ID")
# Out:
#     ID Nombre        Curso           Materia  Calificación
# 0  101    Ana  Matemáticas           Álgebra            85
# 1  101    Ana  Matemáticas         Geometría            90
# 2  102   Juan     Ciencias            Física            88
# 3  102   Juan     Ciencias           Quimica            65
# 4  103   Luis     Historia  Historia Mundial            75

# %% [markdown]
# Por defecto si no se especifica el parametro **how**, este esta configurado como how='inner', lo que conserva solo las filas que tienen coincidencias en ambos DataFrames.

# %%
pd.merge(estudiantes,calificaciones, on ="ID", how='outer')
# Out:
#     ID Nombre        Curso           Materia  Calificación
# 0  101    Ana  Matemáticas           Álgebra          85.0
# 1  101    Ana  Matemáticas         Geometría          90.0
# 2  102   Juan     Ciencias            Física          88.0
# 3  102   Juan     Ciencias           Quimica          65.0
# 4  103   Luis     Historia  Historia Mundial          75.0
# 5  104  María  Matemáticas               NaN           NaN
# 6  105   Jose     Ciencias               NaN           NaN

# %% [markdown]
# **Tipos de joins:**
#
# Si cambiamos el parámetro how, se puede modificar cómo se combinan los DataFrames:
#
# **how='inner'**: Mantiene solo las filas con coincidencias en ambos DataFrames.
#
# **how='outer'**: Mantiene todas las filas de ambos DataFrames, llenando con NaN donde no hay coincidencias.
#
# **how='right'**: Mantiene todas las filas del DataFrame derecho
#
# **how='left'**: Mantiene todas las filas del DataFrame izquierdo

# %%
#Forma de obtener mismo resultado???
pd.merge(estudiantes,calificaciones, on ="ID", how='outer')
# Out:
#     ID Nombre        Curso           Materia  Calificación
# 0  101    Ana  Matemáticas           Álgebra          85.0
# 1  101    Ana  Matemáticas         Geometría          90.0
# 2  102   Juan     Ciencias            Física          88.0
# 3  102   Juan     Ciencias           Quimica          65.0
# 4  103   Luis     Historia  Historia Mundial          75.0
# 5  104  María  Matemáticas               NaN           NaN
# 6  105   Jose     Ciencias               NaN           NaN

# %%
#Tabmien podemos unir datasets usando varias claves
pd.merge(estudiantes,calificaciones,on = ['ID','Curso'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[54], line 2
#       1 #Tabmien podemos unir datasets usando varias claves
# ----> 2 pd.merge(estudiantes,calificaciones,on = ['ID','Curso'])
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\reshape\merge.py:110, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      93 @Substitution("\nleft : DataFrame or named Series")
#      94 @Appender(_merge_doc, indents=0)
#      95 def merge(
#    (...)
#     108     validate: str | None = None,
#     109 ) -> DataFrame:
# --> 110     op = _MergeOperation(
#     111         left,
#     112         right,
#     113         how=how,
#     114         on=on,
#     115         left_on=left_on,
#     116         right_on=right_on,
#     117         left_index=left_index,
#     118         right_index=right_index,
#     119         sort=sort,
#     120         suffixes=suffixes,
#     121         indicator=indicator,
#     122         validate=validate,
#     123     )
#     124     return op.get_result(copy=copy)
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\reshape\merge.py:703, in _MergeOperation.__init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, indicator, validate)
#     696 self._cross = cross_col
#     698 # note this function has side effects
#     699 (
#     700     self.left_join_keys,
#     701     self.right_join_keys,
#     702     self.join_names,
# --> 703 ) = self._get_merge_keys()
#     705 # validate the merge keys dtypes. We may need to coerce
#     706 # to avoid incompatible dtypes
#     707 self._maybe_coerce_merge_keys()
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\reshape\merge.py:1162, in _MergeOperation._get_merge_keys(self)
#    1160 rk = cast(Hashable, rk)
#    1161 if rk is not None:
# -> 1162     right_keys.append(right._get_label_or_level_values(rk))
#    1163 else:
#    1164     # work-around for merge_asof(right_index=True)
#    1165     right_keys.append(right.index)
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\generic.py:1850, in NDFrame._get_label_or_level_values(self, key, axis)
#    1844     values = (
#    1845         self.axes[axis]
#    1846         .get_level_values(key)  # type: ignore[assignment]
#    1847         ._values
#    1848     )
#    1849 else:
# -> 1850     raise KeyError(key)
#    1852 # Check for duplicates
#    1853 if values.ndim > 1:
#
# KeyError: 'Curso'

# %%
#Usando otro ejemplo

# DataFrame de ventas
ventas = pd.DataFrame({
    'Tienda': ['A', 'A', 'B', 'C'],
    'Producto': ['Manzana', 'Plátano', 'Manzana', 'Fresa'],
    'Cantidad': [10, 8, 5, 12]
})

# DataFrame de precios
precios = pd.DataFrame({
    'Tienda': ['A', 'A', 'B', 'C'],
    'Producto': ['Manzana', 'Plátano', 'Manzana', 'Fresa'],
    'Precio': [2.5, 1.2, 2.8, 3.0]
})
ventas
# Out:
#   Tienda Producto  Cantidad
# 0      A  Manzana        10
# 1      A  Plátano         8
# 2      B  Manzana         5
# 3      C    Fresa        12

# %%
precios
# Out:
#   Tienda Producto  Precio
# 0      A  Manzana     2.5
# 1      A  Plátano     1.2
# 2      B  Manzana     2.8
# 3      C    Fresa     3.0

# %%
# Realizamos el merge utilizando dos claves: 'Tienda' y 'Producto'
resultado = pd.merge(ventas, precios, on=['Tienda', 'Producto'], how='inner')
resultado
# Out:
#   Tienda Producto  Cantidad  Precio
# 0      A  Manzana        10     2.5
# 1      A  Plátano         8     1.2
# 2      B  Manzana         5     2.8
# 3      C    Fresa        12     3.0

# %%
# Para alcular el ingreso total por tienda y producto
resultado['Ingreso Total'] = resultado['Cantidad'] * resultado['Precio']

resultado
# Out:
#   Tienda Producto  Cantidad  Precio  Ingreso Total
# 0      A  Manzana        10     2.5           25.0
# 1      A  Plátano         8     1.2            9.6
# 2      B  Manzana         5     2.8           14.0
# 3      C    Fresa        12     3.0           36.0

# %% [markdown]
# **Podemos unir dos dataset a lo largo del eje X**

# %%
pd.merge(ventas, precios, left_index=True, right_index=True)
# Out:
#   Tienda_x Producto_x  Cantidad Tienda_y Producto_y  Precio
# 0        A    Manzana        10        A    Manzana     2.5
# 1        A    Plátano         8        A    Plátano     1.2
# 2        B    Manzana         5        B    Manzana     2.8
# 3        C      Fresa        12        C      Fresa     3.0

# %%
#Otro ejemplo

# %%
#Generamos dataframe sales
Sales = pd.DataFrame({
    'Ventas Totales': [150000, 200000, 180000]
}, index=['Tienda A', 'Tienda B', 'Tienda C'])

# Creamos DataFrame de Regiones
regiones = pd.DataFrame({
    'Región': ['Norte', 'Centro']
}, index=['Tienda A', 'Tienda C'])

# %%
Sales
# Out:
#           Ventas Totales
# Tienda A          150000
# Tienda B          200000
# Tienda C          180000

# %%
regiones
# Out:
#           Región
# Tienda A   Norte
# Tienda C  Centro

# %%
# Realizar la unión por índices
resultado = pd.merge(Sales, regiones, left_index=True, right_index=True)

resultado
# Out:
#           Ventas Totales  Región
# Tienda A          150000   Norte
# Tienda C          180000  Centro

# %% [markdown]
# # Concatenando a lo largo de un eje

# %% [markdown]
# Usamos el metodo contact cuando deseamos unir dos dataset que no comparten palabras clave. Combina datasets apilándolos uno encima de otro (por filas) o uno al lado del otro (por columnas), basándose en la alineación de índices.

# %%
# DataFrame 1
ventas1 = pd.DataFrame({
    'ID_Tienda': [1, 2, 3],
    'Ventas Totales': [150000, 200000, 180000]
})

# DataFrame 2
regiones1 = pd.DataFrame({
    'ID_Tienda': [1, 2, 3],
    'Región': ['Norte', 'Sur', 'Centro']
})
ventas1
# Out:
#    ID_Tienda  Ventas Totales
# 0          1          150000
# 1          2          200000
# 2          3          180000

# %%
regiones1
# Out:
#    ID_Tienda  Región
# 0          1   Norte
# 1          2     Sur
# 2          3  Centro

# %%
#que pasa si ejecuto esta linea de codigo?
pd.merge(ventas1, regiones1, on='ID_Tienda', how='inner')
# Out:
#    ID_Tienda  Ventas Totales  Región
# 0          1          150000   Norte
# 1          2          200000     Sur
# 2          3          180000  Centro

# %%
#Usemos contact
pd.concat([ventas1, regiones1], axis=1)
# Out:
#    ID_Tienda  Ventas Totales  ID_Tienda  Región
# 0          1          150000          1   Norte
# 1          2          200000          2     Sur
# 2          3          180000          3  Centro

# %%
pd.concat([ventas1, regiones1], axis=0)
# Out:
#    ID_Tienda  Ventas Totales  Región
# 0          1        150000.0     NaN
# 1          2        200000.0     NaN
# 2          3        180000.0     NaN
# 0          1             NaN   Norte
# 1          2             NaN     Sur
# 2          3             NaN  Centro

# %%
ventas
# Out:
#   Tienda Producto  Cantidad
# 0      A  Manzana        10
# 1      A  Plátano         8
# 2      B  Manzana         5
# 3      C    Fresa        12

# %%
regiones
# Out:
#           Región
# Tienda A   Norte
# Tienda C  Centro

# %%
#que pasara si?
pd.concat([ventas, regiones], axis=1)
# Out:
#          Tienda Producto  Cantidad  Región
# 0             A  Manzana      10.0     NaN
# 1             A  Plátano       8.0     NaN
# 2             B  Manzana       5.0     NaN
# 3             C    Fresa      12.0     NaN
# Tienda A    NaN      NaN       NaN   Norte
# Tienda C    NaN      NaN       NaN  Centro

# %% [markdown]
# ![mergeVSconcat.png](attachment:mergeVSconcat.png)

# %% [markdown]
# **Metodo combine_first**
# Nos sirve para:
#
# 1. Rellenar datos faltantes (NaN):
#
# 2. Cuando tienes un DataFrame incompleto y deseas completarlo con valores de otro DataFrame o Series que tiene información complementaria.
# 3. Preservar datos existentes:
# 4. Si no quieres sobrescribir los datos ya presentes en el DataFrame original.
#
# Operaciones de consolidación:
#
# Combinar dos fuentes de datos donde una es más confiable o contiene información más reciente y usarla para llenar los huecos de la otra.

# %%
# DataFrame 1: Información incompleta
df1 = pd.DataFrame({
    'A': [1, np.nan, 3],
    'B': [4, np.nan, 6],
    'C': [7, 8, np.nan]
})

# DataFrame 2: Información complementaria
df2 = pd.DataFrame({
    'A': [np.nan, 2, np.nan],
    'B': [np.nan, 5, np.nan],
    'C': [np.nan, np.nan, 9]
})
df1
# Out:
#      A    B    C
# 0  1.0  4.0  7.0
# 1  NaN  NaN  8.0
# 2  3.0  6.0  NaN

# %%
df2
# Out:
#      A    B    C
# 0  NaN  NaN  NaN
# 1  2.0  5.0  NaN
# 2  NaN  NaN  9.0

# %%
df1.combine_first(df2)
# Out:
#      A    B    C
# 0  1.0  4.0  7.0
# 1  2.0  5.0  8.0
# 2  3.0  6.0  9.0

# %% [markdown]
# **Comparación con otros métodos**
#
# **fillna:**
#
# Propósito: Solo llena los valores faltantes con un valor específico o los valores de una Serie/columna.
# Diferencia: fillna no considera otra estructura completa (DataFrame o Series) como fuente para rellenar.
#
# **combine_first:**
# Más poderoso cuando estás trabajando con dos estructuras completas que necesitas combinar, no solo con un valor fijo o una Serie.
#
# **merge o concat:**
# Propósito: Fusionar o concatenar datasets.
# Diferencia: Estos métodos son para combinar datasets por filas o columnas, mientras que combine_first está diseñado específicamente para rellenar datos faltantes de forma inteligente.

# %%
#Practiquemos lo aprendido
